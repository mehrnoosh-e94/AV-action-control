# %%
import numpy as np
import random
import variables as var
import functions as func
import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.stats import norm

# %% [markdown]
# Variable Initialization

# %%
T_Y = var.T_Y  #timing for yellow phase
T_G = var.T_G #timing for green phase
T_R = var.T_R #timing for red phase
total_T = T_Y + T_G + T_R

d_lower = var.d_lower #lower bound for the initial distribution of distance
d_upper = var.d_upper #upper bound for the initial distribution of distance
v_lower = var.v_lower #lower bound for the initial distribution of velocity
v_upper = var.v_upper #upper bound for the initial distribution of velocity

delta_t = var.delta_t

phi_to_T_dict = {'Y': T_Y, 'G': T_G, 'R': T_R} #dictionary to map each phase to its timing
phi_to_next_phi_dict = {'G':'Y', 'Y':'R', 'R':'G'} #dictionary to map each phase to its next phase
phi_prev_phi_dict = var.phi_prev_phi_dict #dictionary to map each phase to its previous phase

std_d= 0.5#var.std_d #standard deviation of distance noise in state process
std_v= 0.25#var.std_v #standard deviation of velocity noise in state process
std_t_phi= 0#var.std_t_phi #standard deviation of timing noise in state process

trials = var.trials #number of runs for Q-learning training phase
episodes = var.episodes #maximum number for the length of the trajectory

learning_rate = 0.001 #learning_rate for the training phase of Q-learning
discount_factor = var.discount_factor #discount factor for the training phase of Q-learning
epsilon = var.epsilon

actions = var.actions #action space
discrete_d = var.discrete_d #list of discrete distances, used for discretization of the distance in state space
v_max= var.v_max #maximum allowed velocity
discrete_v = var.discrete_v #list of discrete velocities, used for discretization of the velocity in state space
discrete_phi_t = var.discrete_phi_t #list of discrete pairs of (phi, t_phi), used for discretization of the (phi, t_phi) in state space

# %%
def possible_states(state, action, std_d, std_v, std_t_phi, phi_to_T_dict, phi_to_next_phi_dict): #finds the possible states that due to the noise we could end up
    possible_states=[]
    
    for i in range(10): #finds the 10 possible states
        new_state = func.update_state(state, action, 1, phi_to_T_dict, phi_to_next_phi_dict, std_d, std_v, std_t_phi,1)
        possible_states.append(new_state)    
    return possible_states

def min_max_q(idx, Q_table):#for the state indexes in idx list, finds the maximum Q-value, and returns the minimum of these Q-vals
    max_q_vals = []
    for i in idx:
        max_q_vals.append(np.max(Q_table[i].flatten()))
    min_q = min(max_q_vals)

    return min_q

# %% [markdown]
# Q-Learning

# %%
Q_table = np.zeros((len(discrete_d)*len(discrete_v)*len(discrete_phi_t), len(actions))) #initialize Q-table
std_d= 0.5#var.std_d
std_v= 0.25#var.std_v
std_t_phi= 0#var.std_t_phi
np.random.seed()

for trial in tqdm(range(trials)):
    idx_i = np.random.randint(0, Q_table.shape[0], 1)[0] #randomly selects a row number of Q-table
    state = func.map_idx_to_state(idx_i, discrete_d, discrete_v, discrete_phi_t) #maps the row number to the state
    distance = state[0]
    velocity = state[1]
    for episode in range(episodes):
        
        if distance<0: #if the vehicle passed the intersection
            break
            
        action, action_idx, not_feasible_index = func.minmax_action_selection(Q_table[idx_i], velocity, actions, epsilon, v_max,1) #action selection based on minmax
        Q_table[idx_i, not_feasible_index]=-1000 #set a high negative value as the q-value for not feasible actions
        q = Q_table[idx_i, action_idx]

        probable_states = possible_states(state, action, std_d, std_v, std_t_phi, phi_to_T_dict, phi_to_next_phi_dict)#finds 10 possible states that the vehicle moves to because of the noise
            
        idx_i_new_list = [func.map_state_to_idx(state_new, discrete_d, discrete_v, discrete_phi_t, T_Y, T_R, phi_prev_phi_dict) for state_new in probable_states]#index of the 10 possible states in Q-table
        min_q = min_max_q(idx_i_new_list, Q_table)#the minimum of the max q-values among 10 possible states
        
        state_new = func.update_state(state, action, delta_t, phi_to_T_dict, phi_to_next_phi_dict, std_d, std_v, std_t_phi,1)#update the staet based on the selected action
        idx_i_new = func.map_state_to_idx(state_new, discrete_d, discrete_v, discrete_phi_t, T_Y, T_R, phi_prev_phi_dict)#finds the index of state in Q-table

        distance = state_new[0]
        velocity = state_new[1]
        phi = state_new[2]
        t_phi = state_new[3]
        
        reward = func.reward_function(distance, velocity, phi, t_phi, v_max, T_Y)#reward of going to the new state

        q = q + learning_rate*(reward + discount_factor*min_q - q)#updating q-value
        Q_table[idx_i,action_idx] = q #update q-table with the new q-value
        
        idx_i = idx_i_new
        state = state_new

with open('MINMAX_Q_table_noise_0.5_0.25_0.npy','wb') as f:#save Q-table
    np.save(f, Q_table)
# Out:
#  24%|██▍       | 951642/4000000 [2:38:36<8:07:52, 104.14it/s]

# %% [markdown]
# Q-Table Loading

# %%
with open('MINMAX_Q_table_noise_0.5_0.25_0.npy','rb') as f:
    Q_table = np.load(f)
print(f'Percentage of non-zero elements in Qtable:{len(Q_table[Q_table!=0])/(Q_table.shape[0]*Q_table.shape[1])}')

# %% [markdown]
# Test Scenario

# %%
# state = (90.55001067682015, 12.032548969195476, 'G', 1)
state=trajectory[0][0]
print('Initial State')
print(state)
print()
idx_i = func.map_state_to_idx(state, discrete_d, discrete_v, discrete_phi_t, T_Y, T_R, phi_prev_phi_dict)
mapped_state = func.map_idx_to_state(idx_i, discrete_d, discrete_v, discrete_phi_t)
distance = mapped_state[0]

while (distance>0):
    print(f'state: {state}')
    action, action_idx = func.action_selection(Q_table[idx_i], velocity, actions, 0, v_max, 0)

    print(f'Q_table for this state:{Q_table[idx_i]}')
    print(f'action: {action}\n')

    state_new = func.update_state(mapped_state, action, delta_t, phi_to_T_dict, phi_to_next_phi_dict, std_d, std_v, std_t_phi,0)
    idx_i_new = func.map_state_to_idx(state_new, discrete_d, discrete_v, discrete_phi_t, T_Y, T_R, phi_prev_phi_dict)
    mapped_state = func.map_idx_to_state(idx_i_new, discrete_d, discrete_v, discrete_phi_t)
    distance = state_new[0]

    state=mapped_state
    idx_i=idx_i_new

print('Final State')
if state[2]=='R':
    print(f"\x1b[31m{state}\x1b[0m")

elif state[2]=='G':
    print(f"\x1b[32m{state}\x1b[0m")
else:
    print(f"\x1b[33m{state}\x1b[0m")
#     print(Q_table[idx_i]) 
print('******************************************************')
# Out:
# Initial State
# (115.72247669903288, 10.508714284043458, 'Y', 0.2220329434276186)
#
# state: (115.72247669903288, 10.508714284043458, 'Y', 0.2220329434276186)
# Q_table for this state:[-0.18077978 -0.18086615 -0.18090316 -0.18100722 -0.1790151  -0.18113422
#  -0.18106569]
# action: 1
#
# state: (105.02402555508777, 11.52238730966237, 'Y', array([1.24919965]))
# Q_table for this state:[-0.30225388 -0.30234221 -0.30253315 -0.30256126 -0.30227456 -0.30197912
#  -0.3036287 ]
# action: 2
#
# state: (92.58625788046594, 13.154460412335006, 'Y', array([2.38322198]))
# Q_table for this state:[-0.22669408 -0.22737049 -0.22722273 -0.22711912 -0.22690539 -0.22696165
#  -0.22684709]
# action: -3
#
# state: (81.71315572259539, 10.103223911452165, 'Y', array([3.24379654]))
# Q_table for this state:[-0.15307847 -0.15186025 -0.15290288 -0.15296268 -0.15213125 -0.1511139
#  -0.15215312]
# action: 2
#
# state: (70.33769628860323, 12.248643718854316, 'Y', array([4.29961125]))
# Q_table for this state:[-0.17689283 -0.17712422 -0.17469318 -0.17621286 -0.17670675 -0.17493483
#  -0.17479924]
# action: -1
#
# state: (58.16180513835825, 10.822815847709188, 'R', array([0.3500906]))
# Q_table for this state:[-0.26313438 -0.26355835 -0.26208012 -0.26344515 -0.262191   -0.26210535
#  -0.26237431]
# action: -1
#
# state: (47.84420932486996, 10.16581691636871, 'R', array([1.52523997]))
# Q_table for this state:[-0.18135118 -0.1819643  -0.18681839 -0.1826388  -0.1853628  -0.18387185
#  -0.19153777]
# action: -3
#
# state: (38.43730658208859, 7.305276001163194, 'R', array([2.60105372]))
# Q_table for this state:[-0.18029693 -0.17958673 -0.18360708 -0.18312067 -0.17974394 -0.18241057
#  -0.18113873]
# action: -2
#
# state: (32.78619675007495, 5.236019893843224, 'R', array([3.69133588]))
# Q_table for this state:[-0.22529468 -0.22576452 -0.22551354 -0.22904039 -0.23104155 -0.23709961
#  -0.22978939]
# action: -3
#
# state: (28.67561323939114, 2.442070060765488, 'R', array([4.87254961]))
# Q_table for this state:[ 0.         -0.15729949 -0.15744045 -0.15910692 -0.15942691 -0.16121698
#  -0.16074209]
# action: -3
#
# state: (28.177394061423318, 0.0, 'R', array([5.98277903]))
# Q_table for this state:[ 0.          0.          0.         -0.16273565 -0.16151307 -0.16118973
#  -0.16117599]
# action: -1
#
# state: (28.902525309657886, 0.0, 'R', array([6.98314402]))
# Q_table for this state:[ 0.          0.          0.         -0.14647564 -0.14846091 -0.14840445
#  -0.14832129]
# action: -1
#
# state: (29.61554698225145, 0.0, 'R', array([8.0357616]))
# Q_table for this state:[ 0.          0.          0.         -0.15254389 -0.15176075 -0.15773518
#  -0.1515778 ]
# action: -1
#
# state: (31.537668145966833, 0.0, 'R', array([9.03436545]))
# Q_table for this state:[ 0.          0.          0.         -0.13971061 -0.14121097 -0.14104697
#  -0.13975708]
# action: -1
#
# state: (32.17027107295883, 0.0, 'G', array([0.25079168]))
# Q_table for this state:[ 0.          0.          0.         -0.18513197 -0.1859489  -0.18606653
#  -0.18437222]
# action: -1
#
# state: (33.65839045730407, 0.0, 'G', array([1.28174995]))
# Q_table for this state:[ 0.          0.          0.         -0.18513197 -0.1859489  -0.18606653
#  -0.18437222]
# action: -1
#
# state: (35.88139186349554, 0.0, 'G', array([2.31239479]))
# Q_table for this state:[ 0.          0.          0.         -0.11294858 -0.11236583 -0.11243304
#  -0.11252933]
# action: -1
#
# state: (36.44261023642656, 0.0, 'G', array([3.34877175]))
# Q_table for this state:[ 0.          0.          0.         -0.08835423 -0.0872139  -0.0872611
#  -0.08731586]
# action: -1
#
# state: (37.53297061371901, 0.0, 'G', array([4.36999099]))
# Q_table for this state:[ 0.          0.          0.         -0.07674669 -0.07749188 -0.07752314
#  -0.07559096]
# action: -1
#
# state: (38.935381946587114, 0.0, 'G', array([5.29155646]))
# Q_table for this state:[ 0.          0.          0.         -0.08443587 -0.08530788 -0.08339727
#  -0.08541813]
# action: -1
#
# state: (39.22216487147241, 0.0, 'G', array([6.53461131]))
# Q_table for this state:[ 0.          0.          0.         -0.0765959  -0.07748019 -0.07751438
#  -0.07756204]
# action: -1
#
# state: (40.806821714785976, 0.0, 'G', array([7.38809521]))
# Q_table for this state:[ 0.          0.          0.         -0.0765959  -0.07748019 -0.07751438
#  -0.07756204]
# action: -1
#
# state: (41.90470483624804, 0.0, 'G', array([8.24516579]))
# Q_table for this state:[ 0.          0.          0.         -0.08239022 -0.08333592 -0.08336861
#  -0.08342889]
# action: -1
#
# state: (42.95423307356334, 0.0, 'G', array([9.23650053]))
# Q_table for this state:[ 0.          0.          0.         -0.0884014  -0.08658285 -0.08715615
#  -0.08701734]
# action: -1
#
# state: (44.14765207253765, 0.0, 'Y', array([0.20969604]))
# Q_table for this state:[ 0.          0.          0.         -0.09837632 -0.0985986  -0.09877213
#  -0.09893465]
# action: -1
#
# state: (44.62249256493373, 0.0, 'Y', array([1.47912723]))
# Q_table for this state:[ 0.          0.          0.         -0.09837632 -0.0985986  -0.09877213
#  -0.09893465]
# action: -1
#
# state: (45.750932571767585, 0.0, 'Y', array([2.29386432]))
# Q_table for this state:[ 0.          0.          0.         -0.07668234 -0.07510278 -0.07567674
#  -0.07620606]
# action: -1
#
# state: (46.4396791766421, 0.0, 'Y', array([3.2365363]))
# Q_table for this state:[ 0.          0.          0.         -0.07111345 -0.07308022 -0.07329259
#  -0.07395565]
# action: -1
#
# state: (47.66523214760657, 0.0, 'Y', array([4.36198531]))
# Q_table for this state:[ 0.          0.          0.         -0.07324495 -0.07214876 -0.07314124
#  -0.07548979]
# action: -1
#
# state: (48.04083825953104, 0.0, 'R', array([0.22858046]))
# Q_table for this state:[ 0.          0.          0.         -0.11051707 -0.11156478 -0.11051203
#  -0.11153711]
# action: -1
#
# state: (50.1721452968682, 0.0, 'R', array([1.17095352]))
# Q_table for this state:[ 0.          0.          0.         -0.11051707 -0.11156478 -0.11051203
#  -0.11153711]
# action: -1
#
# state: (50.357765307359124, 0.0, 'R', array([2.11893383]))
# Q_table for this state:[ 0.          0.          0.         -0.07342109 -0.07545604 -0.07360913
#  -0.07496775]
# action: -1
#
# state: (52.11113207525505, 0.0, 'R', array([3.19411513]))
# Q_table for this state:[ 0.          0.          0.         -0.06317164 -0.06324304 -0.06381662
#  -0.06193476]
# action: -1
#
# state: (53.18137523654855, 0.0, 'R', array([4.15064731]))
# Q_table for this state:[ 0.          0.          0.         -0.07125325 -0.06938146 -0.06958172
#  -0.06973494]
# action: -1
#
# state: (53.88723684119215, 0.0, 'R', array([5.08680105]))
# Q_table for this state:[ 0.          0.          0.         -0.06752254 -0.07273509 -0.07110417
#  -0.06953874]
# action: -1
#
# state: (54.20280807587262, 0.0, 'R', array([6.10725959]))
# Q_table for this state:[ 0.          0.          0.         -0.06714068 -0.0688571  -0.06912309
#  -0.06746544]
# action: -1
#
# state: (54.29803000677424, 0.0, 'R', array([7.01255187]))
# Q_table for this state:[ 0.          0.          0.         -0.06327976 -0.06476264 -0.06517491
#  -0.06532756]
# action: -1
#
# state: (55.95037812375104, 0.0, 'R', array([8.03323173]))
# Q_table for this state:[ 0.          0.          0.         -0.07304969 -0.07477185 -0.07290436
#  -0.07104335]
# action: -1
#
# state: (56.95028241166296, 0.0, 'R', array([8.96986128]))
# Q_table for this state:[ 0.          0.          0.         -0.05737087 -0.0603062  -0.05848948
#  -0.06042252]
# action: -1
#
# state: (58.18631890739741, 0.0, 'R', array([9.87364568]))
# Q_table for this state:[ 0.          0.          0.         -0.02590653 -0.02611073 -0.02615374
#  -0.02617727]
# action: -1
#
# state: (60.00412516885585, 0.0, 'G', array([0.87914832]))
# Q_table for this state:[ 0.          0.          0.         -0.0669143  -0.06746551 -0.06755413
#  -0.06760029]
# action: -1
#
# state: (60.96030369376495, 0.0, 'G', array([1.65505671]))
# Q_table for this state:[ 0.          0.          0.         -0.05150417 -0.05182442 -0.05185946
#  -0.05193609]
# action: -1
#
# state: (61.01379204317456, 0.0, 'G', array([2.77853304]))
# Q_table for this state:[ 0.          0.          0.         -0.04950801 -0.04783831 -0.04593377
#  -0.04599724]
# action: -1
#
# state: (63.102990106389264, 0.0, 'G', array([4.09415563]))
# Q_table for this state:[ 0.          0.          0.         -0.05144835 -0.05184088 -0.05390179
#  -0.04997049]
# action: -1
#
# state: (64.427112230291, 0.0, 'G', array([5.14193459]))
# Q_table for this state:[ 0.          0.          0.         -0.04945212 -0.04986401 -0.04991448
#  -0.04994695]
# action: -1
#
# state: (64.3169162521964, 0.0, 'G', array([6.00782235]))
# Q_table for this state:[ 0.          0.          0.         -0.04752655 -0.04785544 -0.04791158
#  -0.04796195]
# action: -1
#
# state: (65.22017282067463, 0.0, 'G', array([7.05489161]))
# Q_table for this state:[ 0.          0.          0.         -0.0475479  -0.04791032 -0.04598123
#  -0.04602662]
# action: -1
#
# state: (66.33425399035364, 0.0, 'G', array([8.08514188]))
# Q_table for this state:[ 0.          0.          0.         -0.04749204 -0.04591169 -0.04595098
#  -0.04601554]
# action: -1
#
# state: (67.03798279130213, 0.0, 'G', array([9.0122456]))
# Q_table for this state:[ 0.          0.          0.         -0.04172142 -0.04237566 -0.04471609
#  -0.04287192]
# action: -1
#
# state: (68.20392214469612, 0.0, 'Y', array([0.10224775]))
# Q_table for this state:[ 0.          0.          0.         -0.04949975 -0.05056582 -0.05080644
#  -0.05076677]
# action: -1
#
# state: (68.56875740928459, 0.0, 'Y', array([1.01585484]))
# Q_table for this state:[ 0.          0.          0.         -0.04949975 -0.05056582 -0.05080644
#  -0.05076677]
# action: -1
#
# state: (69.96697021141962, 0.0, 'Y', array([2.09943525]))
# Q_table for this state:[ 0.          0.          0.         -0.02994128 -0.03051816 -0.02859383
#  -0.03063601]
# action: -1
#
# state: (70.55015344505962, 0.0, 'Y', array([3.2488005]))
# Q_table for this state:[ 0.          0.          0.         -0.03182478 -0.03256128 -0.03270014
#  -0.0305668 ]
# action: -1
#
# state: (71.54481160774273, 0.0, 'Y', array([4.27144602]))
# Q_table for this state:[ 0.          0.          0.         -0.03776585 -0.03856756 -0.03669309
#  -0.0366433 ]
# action: -1
#
# state: (73.76384283686629, 0.0, 'R', array([0.29894845]))
# Q_table for this state:[ 0.          0.          0.         -0.04760948 -0.04869958 -0.04688478
#  -0.04894385]
# action: -1
#
# state: (75.3398593878108, 0.0, 'R', array([1.1349393]))
# Q_table for this state:[ 0.          0.          0.         -0.04760948 -0.04869958 -0.04688478
#  -0.04894385]
# action: -1
#
# state: (76.54806368115734, 0.0, 'R', array([2.19310124]))
# Q_table for this state:[ 0.          0.          0.         -0.02192254 -0.02233722 -0.02245929
#  -0.02247237]
# action: -1
#
# state: (78.13626758444096, 0.0, 'R', array([3.19407599]))
# Q_table for this state:[ 0.          0.          0.         -0.02389299 -0.02436675 -0.02240417
#  -0.02454418]
# action: -1
#
# state: (79.17146742357221, 0.0, 'R', array([4.19153133]))
# Q_table for this state:[ 0.          0.          0.         -0.02004873 -0.02028665 -0.02035466
#  -0.0205287 ]
# action: -1
#
# state: (80.05282912616842, 0.0, 'R', array([5.27138691]))
# Q_table for this state:[ 0.          0.          0.         -0.02004242 -0.02231214 -0.01825749
#  -0.01832413]
# action: -1
#
# state: (81.28015629787703, 0.0, 'R', array([6.30494006]))
# Q_table for this state:[ 0.          0.          0.         -0.01595928 -0.01823305 -0.01627293
#  -0.01630385]
# action: -1
#
# state: (81.96902290503424, 0.0, 'R', array([7.27609045]))
# Q_table for this state:[ 0.          0.          0.         -0.02189033 -0.02220725 -0.0222466
#  -0.02024288]
# action: -1
#
# state: (83.00973895399336, 0.0, 'R', array([8.30702934]))
# Q_table for this state:[ 0.          0.          0.         -0.01792817 -0.01821511 -0.01827668
#  -0.01628388]
# action: -1
#
# state: (84.68779782535125, 0.0, 'R', array([9.47364048]))
# Q_table for this state:[ 0.          0.          0.         -0.00999718 -0.01002638 -0.01008205
#  -0.0100721 ]
# action: -1
#
# state: (85.93957646733307, 0.0, 'G', array([0.45103608]))
# Q_table for this state:[ 0.          0.          0.         -0.01594411 -0.01403924 -0.01403278
#  -0.01408364]
# action: -1
#
# state: (86.52953439472311, 0.0, 'G', array([1.42252315]))
# Q_table for this state:[ 0.          0.          0.         -0.01594411 -0.01403924 -0.01403278
#  -0.01408364]
# action: -1
#
# state: (86.87807177684442, 0.0, 'G', array([2.44219916]))
# Q_table for this state:[ 0.          0.          0.         -0.01197004 -0.01002045 -0.01002441
#  -0.01005519]
# action: -1
#
# state: (87.98464696550755, 0.0, 'G', array([3.35823674]))
# Q_table for this state:[ 0.          0.          0.         -0.00998002 -0.01003791 -0.01005546
#  -0.00804041]
# action: -1
#
# state: (89.83327578501687, 0.0, 'G', array([4.33925491]))
# Q_table for this state:[ 0.          0.          0.         -0.00998002 -0.01002806 -0.01003367
#  -0.0100501 ]
# action: -1
#
# state: (90.73962744901934, 0.0, 'G', array([5.23934943]))
# Q_table for this state:[ 0.          0.          0.         -0.00998002 -0.01002211 -0.00802257
#  -0.00804375]
# action: -1
#
# state: (92.32561434634601, 0.0, 'G', array([6.37126206]))
# Q_table for this state:[ 0.          0.          0.         -0.003998   -0.00401351 -0.00401922
#  -0.00200961]
# action: -1
#
# state: (93.20417032458359, 0.0, 'G', array([7.33464717]))
# Q_table for this state:[ 0.          0.          0.          0.         -0.00200768  0.
#  -0.0020154 ]
# action: 0
#
# state: (93.73738688582206, 0.0, 'G', array([8.31046393]))
# Q_table for this state:[ 0.          0.          0.         -0.00200576 -0.00201353 -0.00201548
#   0.        ]
# action: -1
#
# state: (94.86508399084123, 0.0, 'G', array([9.30513871]))
# Q_table for this state:[ 0.          0.          0.         -0.003998   -0.00404701 -0.00201548
#  -0.00404025]
# action: -1
#
# state: (96.06730499385885, 0.0, 'Y', array([0.35218456]))
# Q_table for this state:[ 0.          0.          0.         -0.003998   -0.00409355 -0.00203505
#  -0.0020555 ]
# action: -1
#
# state: (97.18056570583326, 0.0, 'Y', array([1.4225425]))
# Q_table for this state:[ 0.          0.          0.         -0.003998   -0.00409355 -0.00203505
#  -0.0020555 ]
# action: -1
#
# state: (99.46965351320146, 0.0, 'Y', array([2.44502345]))
# Q_table for this state:[ 0.          0.          0.         -0.00202877 -0.00406927 -0.00205384
#  -0.00203471]
# action: -1
#
# state: (100.91993494424442, 0.0, 'Y', array([3.49622459]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.73725031337538, 0.024020398402344788, 'Y', array([4.48555977]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.6560151534983, 0.017532266293530985, 'R', array([0.39321263]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.4242678540856, 0.0, 'R', array([1.32058765]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.67689903685901, 0.0, 'R', array([2.27295209]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.35584018942266, 0.0, 'R', array([3.1463025]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.00897672222885, 0.0, 'R', array([4.16469343]))
# Q_table for this state:[ 0.         0.         0.         0.         0.         0.
#  -0.0020191]
# action: 0
#
# state: (100.45622446186908, 0.06557635681880905, 'R', array([5.30185432]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.81452035222586, 0.39910212635191133, 'R', array([6.34541735]))
# Q_table for this state:[ 0.          0.          0.         -0.003998   -0.00403784 -0.00203051
#  -0.00405731]
# action: -1
#
# state: (100.54338524587692, 0.0, 'R', array([7.34216362]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.45031977200719, 0.4497796293950992, 'R', array([8.15664254]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.90580895778368, 0.3848201881822305, 'R', array([9.22158376]))
# Q_table for this state:[ 0.          0.          0.         -0.002      -0.00201341 -0.00201907
#  -0.00201939]
# action: -1
#
# state: (100.24537332209076, 0.0, 'G', array([0.16579866]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.03225427642698, 0.0, 'G', array([1.09892417]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.08152966233376, 0.20944741305574316, 'G', array([2.31155883]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (98.61555840826654, 0.9612490648278402, 'G', array([3.27821058]))
# Q_table for this state:[ 0.          0.         -0.002      -0.00402462 -0.00200968 -0.00200765
#  -0.00200966]
# action: -2
#
# state: (98.86851957315724, 0.0, 'G', array([4.39562947]))
# Q_table for this state:[ 0.          0.          0.          0.          0.          0.
#  -0.00201347]
# action: 0
#
# state: (99.09687874942814, 0.0, 'G', array([5.36587304]))
# Q_table for this state:[ 0.          0.          0.         -0.00201168 -0.0020019  -0.00201359
#  -0.00202519]
# action: -1
#
# state: (100.19977849200627, 0.0, 'G', array([6.31907475]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.85159831373, 0.0, 'G', array([7.37048173]))
# Q_table for this state:[ 0.          0.          0.          0.          0.         -0.00201162
#   0.        ]
# action: 0
#
# state: (100.14868264542653, 0.07589700584776567, 'G', array([8.26354922]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.12593971241077, 0.2274549730127975, 'G', array([9.24543691]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.33387162376849, 0.0, 'Y', array([0.27981282]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.13928942836175, 0.053861324260499444, 'Y', array([1.43332546]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.59703318283479, 0.18731340955114165, 'Y', array([2.35069343]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.78572626609217, 0.43161693302631177, 'Y', array([3.45241189]))
# Q_table for this state:[ 0.          0.          0.         -0.00404131 -0.00203393 -0.00201338
#  -0.00205384]
# action: -1
#
# state: (101.4709412342832, 0.0, 'Y', array([4.42883311]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.7092828650827, 0.0, 'R', array([0.6615215]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (102.02676432924575, 0.0, 'R', array([1.65488162]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (102.15978896874562, 0.0, 'R', array([2.59812044]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (102.30070165288238, 0.18588917456733656, 'R', array([3.69172706]))
# Q_table for this state:[ 0.         0.         0.         0.         0.         0.
#  -0.0020191]
# action: 0
#
# state: (101.61673053046896, 0.08905766682434954, 'R', array([4.59787807]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.05495838524654, 0.14140972159220516, 'R', array([5.8004628]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.33781319909455, 0.634888217149711, 'R', array([6.90952102]))
# Q_table for this state:[ 0.          0.          0.          0.          0.         -0.00203061
#   0.        ]
# action: 0
#
# state: (100.03165164883738, 1.2707494235523136, 'R', array([7.94881104]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.53452609177235, 1.3190641819498647, 'R', array([9.08384822]))
# Q_table for this state:[ 0.          0.         -0.00401738 -0.00403248 -0.00405373 -0.00405202
#  -0.00404794]
# action: -2
#
# state: (98.96451323159745, 0.0, 'G', array([0.04443984]))
# Q_table for this state:[ 0.          0.          0.         -0.003998   -0.00201168 -0.00200769
#  -0.00402887]
# action: -1
#
# state: (100.19898860896232, 0.0, 'G', array([1.15148106]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.58380600484925, 0.0, 'G', array([2.03425701]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.67930952118529, 0.09855054757230758, 'G', array([2.87403364]))
# Q_table for this state:[ 0.          0.          0.         -0.003998   -0.00200948  0.
#  -0.00200572]
# action: -1
#
# state: (99.97438907397031, 0.0, 'G', array([3.91974159]))
# Q_table for this state:[ 0.          0.          0.          0.          0.          0.
#  -0.00201347]
# action: 0
#
# state: (100.01569229149534, 0.15044620857782795, 'G', array([4.83232283]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.82210579271732, 0.0, 'G', array([5.80953727]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.76323862570706, 0.42827196432195125, 'G', array([6.81994835]))
# Q_table for this state:[ 0.          0.          0.          0.          0.         -0.00201162
#   0.        ]
# action: 0
#
# state: (100.3141127092601, 0.08126858642044005, 'G', array([7.85226794]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.53510868399583, 0.0, 'G', array([8.88953206]))
# Q_table for this state:[ 0.          0.          0.         -0.003998   -0.00404701 -0.00201548
#  -0.00404025]
# action: -1
#
# state: (100.33117483673082, 0.0, 'G', array([9.81624623]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.50923000069956, 0.0, 'Y', array([0.85182325]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.68121460359136, 0.0, 'Y', array([1.91703209]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (102.10915059490145, 0.0, 'Y', array([3.02510049]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (102.1426594838778, 0.0, 'Y', array([3.92465429]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (102.32205508551297, 0.0, 'Y', array([4.97221169]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.85604326773596, 0.0, 'R', array([1.17340117]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.43657737740718, 0.24364361732843012, 'R', array([2.22962916]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.26126088326795, 0.18121291049873287, 'R', array([2.98888764]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.6601857079453, 0.26977231405965835, 'R', array([3.98725399]))
# Q_table for this state:[ 0.         0.         0.         0.         0.         0.
#  -0.0020191]
# action: 0
#
# state: (100.12903254154963, 0.353865091401871, 'R', array([5.1577339]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.27758957249496, 0.1817492346236889, 'R', array([6.08503032]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.11176593638443, 0.25270502690534746, 'R', array([7.17259686]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.93924949336255, 0.27746374441649113, 'R', array([8.32286308]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.77056396153463, 0.3427044498781898, 'R', array([9.33002783]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.25573898746421, 0.7152848415068354, 'G', array([0.42610895]))
# Q_table for this state:[ 0.          0.          0.          0.          0.          0.
#  -0.00202513]
# action: 0
#
# state: (99.60010749045563, 0.6905529562877076, 'G', array([1.3567925]))
# Q_table for this state:[ 0.          0.         -0.002      -0.002      -0.00401153 -0.0020154
#  -0.00200381]
# action: -2
#
# state: (100.0900786714492, 0.0, 'G', array([2.40883146]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.15542997878636, 0.11837029116219318, 'G', array([3.31818121]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.42521845187827, 0.4592188082704882, 'G', array([4.35264009]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.02759700510155, 0.45320523605705876, 'G', array([5.45661371]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.125750772361, 0.6290901554293816, 'G', array([6.47792569]))
# Q_table for this state:[ 0.          0.         -0.003998   -0.00400954 -0.00602493 -0.00200765
#  -0.00200767]
# action: -2
#
# state: (99.99540252785914, 0.0, 'G', array([7.57835666]))
# Q_table for this state:[ 0.          0.          0.         -0.00200576 -0.00201353 -0.00201548
#   0.        ]
# action: -1
#
# state: (101.56992256077241, 0.0, 'G', array([8.62930334]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.50923368967769, 0.0, 'G', array([9.68180028]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (102.50119082410629, 0.0, 'Y', array([0.61858988]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.96752813718295, 0.03993215807234377, 'Y', array([1.81062942]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.73319814254832, 0.2667006725182653, 'Y', array([2.60943647]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.59589899531427, 0.3661179242557802, 'Y', array([3.6494593]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.61194181314498, 0.461085345914032, 'Y', array([4.60531771]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.81983147497714, 0.6039547717650376, 'R', array([0.65301092]))
# Q_table for this state:[ 0.     0.     0.    -0.002  0.     0.     0.   ]
# action: -1
#
# state: (101.51657228966575, 0.0, 'R', array([1.65973524]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.72934907905562, 0.33028645792142647, 'R', array([2.63736576]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (102.32864090178686, 0.23652289982882543, 'R', array([3.84642611]))
# Q_table for this state:[ 0.         0.         0.         0.         0.         0.
#  -0.0020191]
# action: 0
#
# state: (102.00393195586233, 0.01292673005149797, 'R', array([4.78193727]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.71442852461702, 0.015209141261632383, 'R', array([5.99900341]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.55688861941559, 0.0, 'R', array([7.05548237]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (102.53475518278393, 0.0, 'R', array([8.04527529]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (102.6448824030937, 0.0, 'R', array([8.9904756]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (102.69820990414975, 0.13945803946127616, 'R', array([9.88063438]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (103.11252490963987, 0.29473150477928656, 'G', array([0.76435221]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.90807785031498, 0.5295841026577963, 'G', array([1.70448817]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.23641523870356, 0.31069807901322855, 'G', array([2.60560876]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.19338808394824, 0.10254013344105536, 'G', array([3.62009774]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.77107546689656, 0.003560138712907862, 'G', array([4.71567361]))
# Q_table for this state:[ 0.          0.          0.         -0.00201168 -0.0020019  -0.00201359
#  -0.00202519]
# action: -1
#
# state: (100.38592955909945, 0.0, 'G', array([5.75836262]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.33444507693336, 0.0024689406739061208, 'G', array([6.6338559]))
# Q_table for this state:[ 0.          0.          0.          0.          0.         -0.00201162
#   0.        ]
# action: 0
#
# state: (100.04983310577055, 0.0, 'G', array([7.7691444]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.17349376345729, 0.4406627817476252, 'G', array([8.77974814]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.00940333219589, 0.7635560191625077, 'G', array([9.79956229]))
# Q_table for this state:[ 0.          0.         -0.002      -0.00202485  0.         -0.00201524
#  -0.00409735]
# action: 1
#
# state: (97.7784913900955, 1.8074255878303618, 'Y', array([0.77435621]))
# Q_table for this state:[ 0.         -0.0080322  -0.00608816 -0.00608047 -0.00608074 -0.00818449
#  -0.00620258]
# action: -3
#
# state: (97.736661549417, 0.0, 'Y', array([1.77819042]))
# Q_table for this state:[ 0.          0.          0.         -0.00202877 -0.00406927 -0.00205384
#  -0.00203471]
# action: -1
#
# state: (99.20692586053482, 0.0, 'Y', array([2.71676708]))
# Q_table for this state:[ 0.          0.          0.         -0.00404131 -0.00203393 -0.00201338
#  -0.00205384]
# action: -1
#
# state: (100.07920287630428, 0.0, 'Y', array([3.60722552]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.45952074844266, 0.2570262201309115, 'Y', array([4.65101344]))
# Q_table for this state:[ 0.          0.          0.         -0.002      -0.00204344 -0.00203279
#  -0.00203437]
# action: -1
#
# state: (100.40528614899713, 0.0, 'R', array([0.68222573]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.4375428995299, 0.07101331472227838, 'R', array([1.73519302]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.94389858336388, 0.009029677113698467, 'R', array([2.76022039]))
# Q_table for this state:[ 0.          0.          0.         -0.0020271  -0.00404763 -0.00405568
#  -0.00202306]
# action: -1
#
# state: (100.58226305413316, 0.0, 'R', array([3.67530749]))
# Q_table for this state:[ 0.         0.         0.         0.         0.         0.
#  -0.0020191]
# action: 0
#
# state: (100.89525306338041, 0.0, 'R', array([4.64313534]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.93189598006106, 0.0, 'R', array([5.70509787]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.03470175968081, 0.2535947011518518, 'R', array([6.69163568]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.64681578998503, 0.0, 'R', array([7.83029182]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.02220179706961, 0.37829508026710296, 'R', array([8.84190639]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.0255108844566, 0.0, 'R', array([9.75826671]))
# Q_table for this state:[ 0.          0.          0.         -0.00201563  0.         -0.0020077
#   0.        ]
# action: -1
#
# state: (100.75496011265142, 0.0, 'G', array([0.84396099]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.11165658592063, 0.06815579705612115, 'G', array([2.08261432]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.55487734134829, 0.04289738113970606, 'G', array([3.14680444]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.5761208485664, 0.20416017062213743, 'G', array([4.10574126]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.95392839748986, 0.25686027134019734, 'G', array([5.09844844]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.10949503836648, 0.011329554839151351, 'G', array([6.1994607]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.30079790266797, 0.17435724965533447, 'G', array([7.17955451]))
# Q_table for this state:[ 0.          0.          0.          0.          0.         -0.00201162
#   0.        ]
# action: 0
#
# state: (100.88625860551403, 0.0, 'G', array([8.19517425]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.96815746065194, 0.31854205453928536, 'G', array([9.39615937]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.05949218407589, 0.14817371610625155, 'Y', array([0.43866596]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.11843301206856, 0.0, 'Y', array([1.42536911]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.65371556775342, 0.270150830012445, 'Y', array([2.41568956]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (102.29174706151822, 0.1599648154055975, 'Y', array([3.43375189]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (102.14994892227888, 0.48894690548504205, 'Y', array([4.39905625]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.23194586154415, 0.7141264727866502, 'R', array([0.38616855]))
# Q_table for this state:[ 0.     0.     0.    -0.002  0.     0.     0.   ]
# action: -1
#
# state: (100.82574527751977, 0.0, 'R', array([1.29604984]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.57068251608287, 0.0, 'R', array([2.22765061]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.34912572916093, 0.0, 'R', array([3.18016805]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.46961762628766, 0.06553248939034269, 'R', array([4.08118613]))
# Q_table for this state:[ 0.         0.         0.         0.         0.         0.
#  -0.0020191]
# action: 0
#
# state: (100.0802479868873, 0.4086974063266127, 'R', array([5.08809549]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.49875784712941, 0.583135663158957, 'R', array([6.0618604]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.47742769655557, 0.2811915912307987, 'R', array([7.04990925]))
# Q_table for this state:[ 0.          0.          0.         -0.00202457 -0.00203811 -0.00405231
#  -0.00204267]
# action: -1
#
# state: (99.86311268926859, 0.0, 'R', array([8.18906072]))
# Q_table for this state:[ 0.          0.          0.         -0.002      -0.00403628 -0.00203051
#  -0.00405954]
# action: -1
#
# state: (101.18779469489499, 0.0, 'R', array([9.30889227]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.43311746451708, 0.08265021076352444, 'G', array([0.33124286]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.58727962848928, 0.33126518355011203, 'G', array([1.23679937]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.0778455828642, 0.17999038622153654, 'G', array([2.23897986]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.76190014642414, 0.1324851126753867, 'G', array([3.35692732]))
# Q_table for this state:[ 0.          0.          0.         -0.003998   -0.00200948  0.
#  -0.00200572]
# action: -1
#
# state: (99.78211279346604, 0.0, 'G', array([4.30036604]))
# Q_table for this state:[ 0.          0.          0.          0.          0.          0.
#  -0.00201347]
# action: 0
#
# state: (100.18685906627677, 0.0, 'G', array([5.30296606]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.21545291170492, 0.11688783133931116, 'G', array([6.26716799]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.61268417959432, 0.2657607524530206, 'G', array([7.38620815]))
# Q_table for this state:[ 0.          0.          0.          0.          0.         -0.00201162
#   0.        ]
# action: 0
#
# state: (100.32862715198816, 0.027933885722155355, 'G', array([8.29443635]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.2446570253478, 0.0, 'G', array([9.29106023]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.52101551510115, 0.16435583929263398, 'Y', array([0.2775836]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.16046319304614, 0.2518213105881591, 'Y', array([1.2734395]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.41204039403951, 0.04586034129579625, 'Y', array([2.20474125]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.23389445645162, 0.0, 'Y', array([3.10154324]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.05196962907074, 0.141573885973331, 'Y', array([3.98993382]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.15913628226131, 0.12383877911990546, 'R', array([0.06629606]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.45334986740508, 0.0, 'R', array([1.04273315]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.15771977969642, 0.0, 'R', array([1.94413368]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.22486087991349, 0.0, 'R', array([2.99295659]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.88696278399486, 0.0, 'R', array([3.98804942]))
# Q_table for this state:[ 0.          0.          0.          0.         -0.0020038  -0.0020267
#  -0.00206057]
# action: 0
#
# state: (100.26724006320326, 0.2379171476540288, 'R', array([4.99330898]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.42008462704527, 0.0, 'R', array([5.96603768]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.54682327322993, 0.24887870196694065, 'R', array([6.9037648]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.89642092285897, 0.2232486360194976, 'R', array([7.82332032]))
# Q_table for this state:[ 0.          0.          0.         -0.002      -0.00403628 -0.00203051
#  -0.00405954]
# action: -1
#
# state: (100.45953732380603, 0.0, 'R', array([8.73848692]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.94467950238612, 0.0, 'R', array([9.76141299]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.20526065319419, 0.0, 'G', array([0.66171696]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.545710562424, 0.0, 'G', array([1.5557633]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.64282862763798, 0.1617214561158461, 'G', array([2.67855663]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.17053106925934, 0.0, 'G', array([3.64449083]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.91748751609781, 0.0, 'G', array([4.65109384]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.23515749511718, 0.39457173766347803, 'G', array([5.58913876]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.82106668854153, 0.5410058305810055, 'G', array([6.51542623]))
# Q_table for this state:[ 0.          0.          0.          0.          0.          0.
#  -0.00200966]
# action: 0
#
# state: (100.4749968916283, 0.5537245925593985, 'G', array([7.34098622]))
# Q_table for this state:[ 0.          0.          0.          0.          0.          0.
#  -0.00200966]
# action: 0
#
# state: (99.36634601469001, 0.7559885041674673, 'G', array([8.34262419]))
# Q_table for this state:[ 0.          0.         -0.002      -0.00602903 -0.0060368  -0.00402126
#  -0.00403909]
# action: -2
#
# state: (100.19520807392098, 0.0, 'G', array([9.33620686]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.83748483374976, 0.0, 'Y', array([0.25842046]))
# Q_table for this state:[ 0.          0.          0.         -0.003998   -0.00409355 -0.00203505
#  -0.0020555 ]
# action: -1
#
# state: (100.59859138666464, 0.0, 'Y', array([1.26578894]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.79172233904035, 0.08093876966828052, 'Y', array([2.26466859]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.52257870128194, 0.12551934645066087, 'Y', array([3.26098168]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.3896512703915, 0.23178205657581796, 'Y', array([4.24289079]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.78962038035819, 0.3527065614118715, 'R', array([0.23417467]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.99690225515927, 0.26638023419341644, 'R', array([1.14228886]))
# Q_table for this state:[ 0.          0.          0.         -0.00402817 -0.0040251  -0.00203074
#  -0.00407834]
# action: -1
#
# state: (100.05823260736945, 0.0, 'R', array([1.98229921]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.7898212724802, 0.04541921318395231, 'R', array([2.93245569]))
# Q_table for this state:[ 0.          0.          0.         -0.0020271  -0.00404763 -0.00405568
#  -0.00202306]
# action: -1
#
# state: (99.95429504397183, 0.0, 'R', array([3.7186274]))
# Q_table for this state:[ 0.          0.          0.          0.         -0.0020038  -0.0020267
#  -0.00206057]
# action: 0
#
# state: (100.14401186535687, 0.2537280324334271, 'R', array([4.84120212]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.49017023893231, 0.02262077436094878, 'R', array([5.73393248]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.36680817121442, 0.0, 'R', array([6.66331114]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.71026335766774, 0.0, 'R', array([7.65069547]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.79769350275785, 0.0, 'R', array([8.63855173]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.02023030381261, 0.0, 'R', array([9.70070767]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.13823393868356, 0.05849504167033651, 'G', array([0.61081961]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.31106551693334, 0.13696710482200544, 'G', array([1.61402844]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.67116305402513, 0.0, 'G', array([2.52685289]))
# Q_table for this state:[ 0.          0.          0.         -0.003998   -0.00200948  0.
#  -0.00200572]
# action: -1
#
# state: (100.56699990814438, 0.0, 'G', array([3.62055592]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.80096361792305, 0.1865353750946495, 'G', array([4.65029146]))
# Q_table for this state:[ 0.          0.          0.         -0.00201168 -0.0020019  -0.00201359
#  -0.00202519]
# action: -1
#
# state: (100.13652568493778, 0.0, 'G', array([5.50561397]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.28766690680457, 0.13884058764312404, 'G', array([6.42048359]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.45785696881555, 0.09768494888779639, 'G', array([7.41026162]))
# Q_table for this state:[ 0.          0.          0.          0.          0.         -0.00201162
#   0.        ]
# action: 0
#
# state: (100.03886935400791, 0.06817659963106965, 'G', array([8.42057916]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.39576245366182, 0.0, 'G', array([9.33078763]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.56579411012214, 0.16709744531849122, 'Y', array([0.24787534]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.63044565265942, 0.6359678296586093, 'Y', array([1.38553619]))
# Q_table for this state:[ 0.          0.          0.         -0.00404999  0.         -0.00205656
#   0.        ]
# action: -1
#
# state: (100.1842856713972, 0.0, 'Y', array([2.45594082]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.62505680455625, 0.0, 'Y', array([3.53568063]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.14706262629154, 0.30769591560665577, 'Y', array([4.51511149]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.06316273482267, 0.6976715447019649, 'R', array([0.38577829]))
# Q_table for this state:[ 0.     0.     0.    -0.002  0.     0.     0.   ]
# action: -1
#
# state: (100.43287402591844, 0.0, 'R', array([1.42719672]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.80375298847504, 0.16679911257086624, 'R', array([2.48225432]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.32024983703045, 0.14945329229369805, 'R', array([3.59911377]))
# Q_table for this state:[ 0.         0.         0.         0.         0.         0.
#  -0.0020191]
# action: 0
#
# state: (101.48210295784652, 0.4363141126871499, 'R', array([4.57263418]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.12573427673064, 0.710329231193332, 'R', array([5.55702801]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.30066781283251, 0.6714599085471219, 'R', array([6.61380981]))
# Q_table for this state:[ 0.          0.         -0.003998   -0.0020038  -0.00203439 -0.00204997
#  -0.00202673]
# action: -2
#
# state: (100.30790914242387, 0.0, 'R', array([7.63448606]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.45562136371785, 0.12385150365241426, 'R', array([8.54143475]))
# Q_table for this state:[ 0.          0.          0.         -0.002      -0.00201341 -0.00201907
#  -0.00201939]
# action: -1
#
# state: (99.5333411050488, 0.0, 'R', array([9.59974701]))
# Q_table for this state:[ 0.          0.          0.         -0.00201563  0.         -0.0020077
#   0.        ]
# action: -1
#
# state: (100.99940304713778, 0.0, 'G', array([0.59253361]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.97452749602978, 0.21173503037657812, 'G', array([1.60707109]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.31271245443816, 0.0, 'G', array([2.64979071]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.31734353148238, 0.08931736378524989, 'G', array([3.5315324]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.28834243080888, 0.3267945757678944, 'G', array([4.55253171]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.85802795036297, 0.5011404578343733, 'G', array([5.45014583]))
# Q_table for this state:[ 0.          0.         -0.003998   -0.00401934 -0.00200964 -0.00200765
#  -0.00201737]
# action: -2
#
# state: (100.44150110313164, 0.0, 'G', array([6.44158268]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.29596267522089, 0.004440390973308884, 'G', array([7.49026634]))
# Q_table for this state:[ 0.          0.          0.          0.         -0.00200768  0.
#  -0.0020154 ]
# action: 0
#
# state: (99.93643261113577, 0.11168775454248289, 'G', array([8.53676399]))
# Q_table for this state:[ 0.          0.          0.         -0.003998   -0.00404701 -0.00201548
#  -0.00404025]
# action: -1
#
# state: (100.66655561866999, 0.0, 'G', array([9.45581921]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.54438301627836, 0.0, 'Y', array([0.53933419]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.15373961323083, 0.0, 'Y', array([1.67922216]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.56747622684762, 0.0, 'Y', array([2.74005897]))
# Q_table for this state:[ 0.          0.          0.         -0.00404131 -0.00203393 -0.00201338
#  -0.00205384]
# action: -1
#
# state: (99.15412796636954, 0.0, 'Y', array([3.73540137]))
# Q_table for this state:[ 0.          0.          0.         -0.002      -0.00404814 -0.00203458
#  -0.00405951]
# action: -1
#
# state: (99.62137150521262, 0.0, 'Y', array([4.86111724]))
# Q_table for this state:[ 0.          0.          0.         -0.002      -0.00204344 -0.00203279
#  -0.00203437]
# action: -1
#
# state: (101.16324415011138, 0.0, 'R', array([0.87358567]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.74462064778452, 0.0, 'R', array([1.95142175]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.15340993796126, 0.0, 'R', array([2.9732164]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.18234269246948, 0.0, 'R', array([3.95667109]))
# Q_table for this state:[ 0.         0.         0.         0.         0.         0.
#  -0.0020191]
# action: 0
#
# state: (101.96916730638604, 0.0, 'R', array([4.99943115]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.5148852837472, 0.175930989915491, 'R', array([5.81913027]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.13987621784258, 0.16744913857501836, 'R', array([6.96868093]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.90322971682934, 0.3436247144248108, 'R', array([8.00559454]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.97714623373342, 0.464186341652882, 'R', array([8.76969033]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.99630896126386, 0.4067775548258775, 'R', array([9.80083452]))
# Q_table for this state:[ 0.          0.          0.         -0.00201563  0.         -0.0020077
#   0.        ]
# action: -1
#
# state: (100.43351127654394, 0.0, 'G', array([0.71081213]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.4346970468492, 0.3642364028712584, 'G', array([1.75799855]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.93406018389481, 0.584487069187253, 'G', array([2.66616641]))
# Q_table for this state:[ 0.          0.         -0.002      -0.00402462 -0.00200968 -0.00200765
#  -0.00200966]
# action: -2
#
# ...
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.97711147819763, 0.20635184378959198, 'G', array([5.04426679]))
# Q_table for this state:[ 0.          0.          0.         -0.00201168 -0.0020019  -0.00201359
#  -0.00202519]
# action: -1
#
# state: (100.15276701920266, 0.0, 'G', array([6.05019216]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.10507298876088, 0.035575706289856485, 'G', array([7.1852508]))
# Q_table for this state:[ 0.          0.          0.          0.          0.         -0.00201162
#   0.        ]
# action: 0
#
# state: (99.3104800799632, 0.0, 'G', array([8.13321662]))
# Q_table for this state:[ 0.          0.          0.         -0.00200576 -0.00201353 -0.00201548
#   0.        ]
# action: -1
#
# state: (100.5690032514169, 0.0, 'G', array([9.29764316]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.67223346793315, 0.0, 'Y', array([0.31939276]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.93011485599358, 0.0, 'Y', array([1.30523986]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.82680217186318, 0.2566092606566944, 'Y', array([2.20801132]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.63182337832819, 0.2522802519120271, 'Y', array([3.03687143]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.26750183345993, 0.0, 'Y', array([3.94819441]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.88343094930852, 0.0, 'Y', array([4.79249112]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.7008015578487, 0.07494972672020109, 'R', array([0.74866896]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.73269319253087, 0.0, 'R', array([1.81689479]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.94917663871263, 0.30944980545621076, 'R', array([2.73288872]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (102.02247333043869, 0.2185853417895861, 'R', array([3.85116208]))
# Q_table for this state:[ 0.         0.         0.         0.         0.         0.
#  -0.0020191]
# action: 0
#
# state: (103.21447552579856, 0.16152644698367846, 'R', array([4.73279767]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (103.86836058602354, 0.28858999498802185, 'R', array([5.7982888]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (103.31751399355392, 0.5842020080179586, 'R', array([6.73697338]))
# Q_table for this state:[ 0.          0.          0.          0.          0.         -0.00203061
#   0.        ]
# action: 0
#
# state: (102.76544147718278, 0.539209200840821, 'R', array([7.87351306]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (102.32826850528612, 0.3768116965378422, 'R', array([8.84917627]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (102.35438748961187, 0.08031477014847499, 'R', array([9.7852774]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (102.87992262295063, 0.06698091907469315, 'G', array([0.59953628]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (102.70533879947324, 0.14597169890133246, 'G', array([1.30373462]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (102.33198533962283, 0.16440926334058567, 'G', array([2.31148819]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (102.44059196849297, 0.2683610288777958, 'G', array([3.36724782]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (102.16834230820967, 0.29564759319175493, 'G', array([4.31025042]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.98763999658843, 0.55798794454336, 'G', array([5.3292843]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.65911007411685, 0.6281607997679062, 'G', array([6.31383563]))
# Q_table for this state:[ 0.          0.          0.          0.         -0.00200964  0.
#   0.        ]
# action: 0
#
# state: (100.53135866025892, 1.146966887823877, 'G', array([7.2654968]))
# Q_table for this state:[ 0.          0.          0.          0.          0.          0.
#  -0.00200966]
# action: 0
#
# state: (99.61613427312636, 1.626253258119964, 'G', array([8.1990456]))
# Q_table for this state:[ 0.         -0.002      -0.00401538 -0.0020116  -0.00201562 -0.00400567
#  -0.00200968]
# action: -3
#
# state: (100.21192279705303, 0.0, 'G', array([9.06115194]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.88601079794664, 0.20453534575982935, 'G', array([9.98572841]))
# Q_table for this state:[ 0.          0.          0.          0.          0.         -0.00203249
#   0.        ]
# action: 0
#
# state: (99.48263526072319, 0.15156890380055255, 'Y', array([0.9262004]))
# Q_table for this state:[ 0.          0.          0.         -0.003998   -0.00409355 -0.00203505
#  -0.0020555 ]
# action: -1
#
# state: (100.19026336970327, 0.0, 'Y', array([1.9930783]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.30233940238158, 0.6178059706673822, 'Y', array([3.14461377]))
# Q_table for this state:[ 0.          0.         -0.003998   -0.00407623 -0.00403049 -0.00407297
#  -0.00203243]
# action: -2
#
# state: (99.6541893869361, 0.0, 'Y', array([3.99864574]))
# Q_table for this state:[ 0.          0.          0.         -0.002      -0.00404814 -0.00203458
#  -0.00405951]
# action: -1
#
# state: (100.36511208510676, 0.0, 'Y', array([4.90429662]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.50983690523324, 0.0, 'R', array([0.91029871]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.64216473495713, 0.0, 'R', array([1.90438341]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.95888789574138, 0.20359409254906288, 'R', array([3.03647066]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.76438729803145, 0.8591886127238932, 'R', array([3.97764331]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.92674171798504, 0.6612638054577461, 'R', array([4.98712043]))
# Q_table for this state:[ 0.          0.         -0.005994   -0.00603614 -0.00402099 -0.00404619
#  -0.00408133]
# action: -2
#
# state: (100.98563635608387, 0.0, 'R', array([5.97395393]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.23664696793259, 0.0, 'R', array([7.00749793]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.07426693377418, 0.19935793854973408, 'R', array([8.04630475]))
# Q_table for this state:[ 0.          0.          0.         -0.002      -0.00403628 -0.00203051
#  -0.00405954]
# action: -1
#
# state: (99.97791498707957, 0.0, 'R', array([9.28027545]))
# Q_table for this state:[ 0.          0.          0.         -0.002      -0.00201341 -0.00201907
#  -0.00201939]
# action: -1
#
# state: (99.89674789601554, 0.0, 'G', array([0.25352187]))
# Q_table for this state:[ 0.          0.          0.         -0.003998   -0.00201168 -0.00200769
#  -0.00402887]
# action: -1
#
# state: (100.94250404458103, 0.0, 'G', array([1.17954228]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.9161232380802, 0.053315806460933, 'G', array([2.18616194]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.76439311469612, 0.15200984100283854, 'G', array([3.09584234]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.36777027468831, 0.0, 'G', array([4.10723878]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.81047764274054, 0.0, 'G', array([5.17592735]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.00746819625675, 0.0, 'G', array([6.10257434]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.45446849101067, 0.2596743141207383, 'G', array([7.08565195]))
# Q_table for this state:[ 0.          0.          0.          0.         -0.00200768  0.
#  -0.0020154 ]
# action: 0
#
# state: (99.24368302347236, 0.7667877561708434, 'G', array([8.02016918]))
# Q_table for this state:[ 0.          0.         -0.002      -0.00602903 -0.0060368  -0.00402126
#  -0.00403909]
# action: -2
#
# state: (99.4074272189509, 0.0, 'G', array([8.94482809]))
# Q_table for this state:[ 0.          0.          0.         -0.003998   -0.00404701 -0.00201548
#  -0.00404025]
# action: -1
#
# state: (100.14743704344401, 0.0, 'Y', array([0.07874189]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.89080644455677, 0.0, 'Y', array([1.00072514]))
# Q_table for this state:[ 0.          0.          0.         -0.003998   -0.00409355 -0.00203505
#  -0.0020555 ]
# action: -1
#
# state: (100.62067845147385, 0.0, 'Y', array([1.84035016]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.69087313301554, 0.0, 'Y', array([2.81267992]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.66299344446462, 0.10044311213795018, 'Y', array([3.84108649]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.78170646145925, 0.0, 'Y', array([4.81267258]))
# Q_table for this state:[ 0.          0.          0.         -0.002      -0.00204344 -0.00203279
#  -0.00203437]
# action: -1
#
# state: (100.67191226093897, 0.0, 'R', array([0.66456241]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.31517291053052, 0.24116558973036123, 'R', array([1.82873038]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.58152466556986, 0.4759735344459448, 'R', array([2.81768059]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.18109715477406, 0.35241963054988795, 'R', array([3.80138484]))
# Q_table for this state:[ 0.          0.          0.          0.         -0.0020038  -0.0020267
#  -0.00206057]
# action: 0
#
# state: (98.84151255344442, 0.39108199419295003, 'R', array([4.86224333]))
# Q_table for this state:[ 0.        0.        0.       -0.002    -0.002034  0.        0.      ]
# action: -1
#
# state: (99.50138020549855, 0.0, 'R', array([5.67596906]))
# Q_table for this state:[ 0.          0.          0.         -0.003998   -0.00403784 -0.00203051
#  -0.00405731]
# action: -1
#
# state: (100.48349613675752, 0.0, 'R', array([6.71227028]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.41303973675798, 0.0, 'R', array([7.76084722]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.0258664897563, 0.08463271427848826, 'R', array([8.74954813]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.46845334424752, 0.40608157883736373, 'R', array([9.70665204]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.46025472085167, 0.25241185278992745, 'G', array([0.5730079]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.88556522081474, 0.2844974137198447, 'G', array([1.64621944]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.79255275168508, 0.0, 'G', array([2.5637893]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.12511320880171, 0.0, 'G', array([3.4534276]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.43158668758967, 0.0, 'G', array([4.40147273]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.21605397535086, 0.09843177459556171, 'G', array([5.43058292]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.46152545486753, 0.0, 'G', array([6.45875412]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.99554310736781, 0.0, 'G', array([7.45938385]))
# Q_table for this state:[ 0.          0.          0.          0.         -0.00200768  0.
#  -0.0020154 ]
# action: 0
#
# state: (99.61740727668386, 0.005457219889726492, 'G', array([8.43641645]))
# Q_table for this state:[ 0.          0.          0.         -0.00200576 -0.00201353 -0.00201548
#   0.        ]
# action: -1
#
# state: (101.07164982942037, 0.0, 'G', array([9.48922694]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.29800372074376, 0.2561576274097312, 'Y', array([0.41052443]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.50043447482163, 0.40609330791865156, 'Y', array([1.48629237]))
# Q_table for this state:[ 0.          0.          0.         -0.003998   -0.00409355 -0.00203505
#  -0.0020555 ]
# action: -1
#
# state: (99.00194476101186, 0.0, 'Y', array([2.40694752]))
# Q_table for this state:[ 0.          0.          0.         -0.00202877 -0.00406927 -0.00205384
#  -0.00203471]
# action: -1
#
# state: (100.45291170238268, 0.0, 'Y', array([3.46350273]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.95120703190179, 0.0, 'Y', array([4.51266305]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.51059717045386, 0.15125384381451368, 'R', array([0.44450206]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.93434097758912, 0.0, 'R', array([1.41124784]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (102.14985819499708, 0.08134442134866443, 'R', array([2.48820995]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (102.59988337133132, 0.10899846100790439, 'R', array([3.48993525]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.3145312335528, 0.2901505069013185, 'R', array([4.43540082]))
# Q_table for this state:[ 0.         0.         0.         0.         0.         0.
#  -0.0020191]
# action: 0
#
# state: (100.33522883045991, 0.03414979466340329, 'R', array([5.36791797]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.5482617086677, 0.10145310449331445, 'R', array([6.38074128]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (99.88237813026316, 0.08671821310689447, 'R', array([7.38100814]))
# Q_table for this state:[ 0.          0.          0.         -0.00202457 -0.00203811 -0.00405231
#  -0.00204267]
# action: -1
#
# state: (100.53397208567641, 0.0, 'R', array([8.19342641]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.99573919011516, 0.0, 'R', array([9.20283549]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (100.71836616072814, 0.04814847109243125, 'G', array([0.17147122]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.35192172960387, 0.0, 'G', array([1.21916302]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.36884153906713, 0.2439374132425781, 'G', array([2.21116606]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
#
# state: (101.19004619080482, 0.5725528465488784, 'G', array([3.24604822]))
# Q_table for this state:[0. 0. 0. 0. 0. 0. 0.]
# action: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-b5b0fea22df3> in <module>
#      23
#      24     state_new = func.update_state(state, action, delta_t, phi_to_T_dict, phi_to_next_phi_dict, std_d, std_v, std_t_phi,0)
# ---> 25     idx_i_new = func.map_state_to_idx(state_new, discrete_d, discrete_v, discrete_phi_t, T_Y, T_R)
#      26     # mapped_state_new = map_idx_to_state(idx_i_new, discrete_d, discrete_v, discrete_phi_t)
#      27     distance = state_new[0]
#
# ~/ondemand/data/functions.py in map_state_to_idx(state, discrete_d, discrete_v, discrete_phi_t, T_Y, T_R)
#     735
#     736     distance_diff = np.asarray([(distance - d)**2 for d in discrete_d])
# --> 737     distance_idx = np.argmin(distance_diff)
#     738
#     739     velocity_diff = np.asarray([(velocity - v)**2 for v in discrete_v])
#
# <__array_function__ internals> in argmin(*args, **kwargs)
#
# /shared/centos7/anaconda3/2021.05/lib/python3.8/site-packages/numpy/core/fromnumeric.py in argmin(a, axis, out)
#    1272
#    1273     """
# -> 1274     return _wrapfunc(a, 'argmin', axis=axis, out=out)
#    1275
#    1276
#
# /shared/centos7/anaconda3/2021.05/lib/python3.8/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56
#      57     try:
# ---> 58         return bound(*args, **kwds)
#      59     except TypeError:
#      60         # A TypeError occurs if the object does have such a method in its
#
# KeyboardInterrupt:
